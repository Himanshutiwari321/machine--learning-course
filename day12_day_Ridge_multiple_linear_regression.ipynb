# %% [markdown]
# ### ridge multiple linear regrassion by SKlearn

# %%
import numpy as np

from sklearn.datasets import load_diabetes

X, y =load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split (X,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import Ridge
rg = Ridge(alpha=0.1,solver='cholesky')

# %%
rg.fit(X_train,y_train)
Ridge()
y_pred = rg.predict(X_test)

# %%
rg.coef_
# Out:
# array([  44.02063391, -241.69329987,  452.98665299,  332.04420177,
#         -76.33686744,  -68.52143809, -164.98809083,  149.96908118,
#         431.61347417,   58.51862681])

# %%
rg.intercept_
# Out:
# np.float64(150.89053425602808)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4693128853309805

# %% [markdown]
# ### ridge regression y own class

# %%
class   MeraRidge:
    
    def __init__(self,alpha=0.1):
        self.coef_ = None
        self.intercept_ = None 
        self.alphas = alpha  

    def fit (self, X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)
        I = np.identity(X_train.shape[1])
        I[0][0] = 0

        result = np.linalg.inv(np.dot(X_train.T,X_train) + self.alphas*I).dot(X_train.T).dot(y_train)

        self.intercept_ = result[0]
        self.coef_ = result [1:]
        

    def predict (self,X_test):
        return np.dot (X_test,self.coef_)  + self.intercept_

# %%
reg = MeraRidge()
reg.fit (X_train,y_train)
y_pred = reg.predict(X_test)

# %%
reg.coef_
# Out:
# array([  44.02063391, -241.69329987,  452.98665299,  332.04420177,
#         -76.33686744,  -68.52143809, -164.98809083,  149.96908118,
#         431.61347417,   58.51862681])

# %%
reg.intercept_
# Out:
# np.float64(150.8905342560281)

# %%
from sklearn.metrics import r2_score 

r2_score (y_test,y_pred)
# Out:
# 0.4693128853309805
