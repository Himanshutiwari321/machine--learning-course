# %% [markdown]
# ### k- means clustering 2d data

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("student_clustering.csv")
df.shape
# Out:
# (200, 2)

# %%
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
import matplotlib.pyplot as plt 
plt.scatter(df["cgpa"],df["iq"])

# %% [markdown]
# ### step-1

# %%
from sklearn.cluster import KMeans

# %%
wcss =[]

for i in range (1,11):
 km =KMeans(n_clusters=i)
 km.fit_predict(df)
 wcss.append(km.inertia_)

# %%
wcss
# Out:
# [29957.898288000004,
#  4184.141270000001,
#  2364.005583420084,
#  681.9696600000003,
#  523.7131894763967,
#  437.48049222807026,
#  351.84925275597413,
#  300.50123741913643,
#  207.8841779384139,
#  177.5985882555226]

# %%
plt.plot(range(1,11),wcss)

# %% [markdown]
# ### step-2

# %%
X = df.iloc[:,:].values
km = KMeans(n_clusters=4)
y_means = km.fit_predict(X)

y_means
# Out:
# array([2, 3, 0, 0, 3, 3, 0, 1, 3, 0, 2, 3, 0, 2, 3, 0, 3, 0, 3, 3, 0, 2,
#        0, 2, 2, 0, 2, 1, 0, 3, 1, 3, 1, 3, 0, 0, 1, 3, 2, 3, 2, 0, 0, 2,
#        1, 1, 0, 3, 1, 3, 2, 2, 1, 0, 1, 3, 3, 1, 3, 1, 3, 0, 0, 1, 2, 1,
#        0, 2, 3, 0, 3, 1, 0, 2, 3, 1, 3, 1, 2, 0, 0, 1, 3, 2, 1, 2, 1, 3,
#        1, 3, 1, 1, 0, 2, 0, 0, 1, 0, 2, 1, 3, 2, 2, 1, 2, 2, 0, 2, 1, 1,
#        0, 1, 3, 3, 0, 1, 0, 3, 1, 2, 2, 3, 0, 1, 0, 2, 0, 3, 2, 0, 0, 3,
#        2, 2, 3, 1, 3, 2, 0, 0, 0, 2, 3, 2, 2, 1, 2, 1, 3, 2, 1, 2, 1, 1,
#        2, 0, 3, 1, 3, 0, 2, 1, 3, 0, 1, 2, 3, 2, 2, 1, 1, 3, 1, 2, 2, 0,
#        1, 3, 2, 1, 1, 3, 3, 3, 0, 2, 0, 0, 1, 3, 0, 0, 2, 2, 0, 2, 1, 3,
#        3, 1], dtype=int32)

# %%
X[y_means==3,0],X[y_means==3,1]
# Out:
# (array([5.9 , 5.45, 5.88, 5.79, 6.1 , 5.71, 5.5 , 6.05, 5.84, 5.43, 6.01,
#         5.32, 5.91, 5.57, 6.4 , 5.67, 6.05, 5.85, 5.87, 6.02, 5.77, 6.06,
#         5.55, 5.81, 5.47, 5.74, 5.8 , 5.88, 5.91, 5.67, 5.74, 5.69, 6.05,
#         6.14, 5.74, 5.94, 5.86, 6.38, 6.61, 6.04, 6.24, 6.1 , 5.8 , 5.87,
#         5.97, 6.17, 6.01, 6.33, 5.85, 6.23]),
#  array([113., 110., 109., 110., 110., 108., 111., 111., 113., 106., 112.,
#         106., 108., 113., 108., 109., 108., 111., 109., 104., 111., 109.,
#         109., 112., 111., 109., 108., 110., 109., 111., 108., 109., 109.,
#         111., 112., 109., 111., 107., 111., 110., 108., 109., 110., 108.,
#         108., 110., 107., 111., 112., 108.]))

# %%
plt.scatter(X[y_means==0,0],X[y_means==0,1],color="blue")
plt.scatter(X[y_means==1,0],X[y_means==1,1],color="red")
plt.scatter(X[y_means==2,0],X[y_means==2,1],color="green")
plt.scatter(X[y_means==3,0],X[y_means==3,1],color="yellow")

# %%
### red = cgpa and iq both are high ---- smart and hardworking 
### blue= cgpa high but iq is low ----- means hardworking student 
### yellow =iq high but cgpa is low ----- means smart but not utilize their smartness
### green low iq and low cgpa ------- will have doing work hard

# %% [markdown]
# ### k -means on 3-d data

# %%
from sklearn.datasets import make_blobs

centroids = [(-5,-5,5),(5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
cluster_std = [1,1,1,1]

X,y = make_blobs(n_samples=200,cluster_std=cluster_std,centers=centroids,n_features=3,random_state=1)

# %%
X
# Out:
# array([[ 4.33424548,  3.32580419, -4.17497018],
#        [-3.32246719,  3.22171129, -4.625342  ],
#        [-6.07296862, -4.13459237,  2.6984613 ],
#        [ 6.90465871,  6.1110567 , -4.3409502 ],
#        [-2.60839207,  2.95015551, -2.2346649 ],
#        [ 5.88490881,  4.12271848, -5.86778722],
#        [-4.68484061, -4.15383935,  4.14048406],
#        [-1.82542929,  3.96089238, -3.4075272 ],
#        [-5.34385368, -4.95640314,  4.37999916],
#        [ 4.91549197,  4.70263812, -4.582698  ],
#        [-3.80108212, -4.81484358,  4.62471505],
#        [ 4.6735005 ,  3.65732421, -3.88561702],
#        [-6.23005814, -4.4494625 ,  5.79280687],
#        [-3.90232915,  2.95112294, -4.6949209 ],
#        [ 3.72744124,  5.31354772, -4.49681519],
#        [-3.3088472 ,  3.05743945, -3.81896126],
#        [ 2.70273021, -2.21732429,  3.17390257],
#        [ 4.06438286, -0.36217193,  3.214466  ],
#        [ 4.69268607, -2.73794194,  5.15528789],
#        [ 4.1210827 , -1.5438783 ,  3.29415949],
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(x=X[:,0],y=X[:,1], z=X[:,2]) #example --- x=X[:,0] sari row s lekin colum sirf 0 idex wala 
fig.show()

# %%
wcss =[]

for i in range (1,11):
 km =KMeans(n_clusters=i)
 km.fit_predict(X)
 wcss.append(km.inertia_)

# %%
wcss
# Out:
# [11143.784324503365,
#  4122.409557603532,
#  2163.269450436297,
#  593.2516262404544,
#  555.7504355163851,
#  491.5231084956422,
#  465.8855994990638,
#  459.07049194576933,
#  418.2065881251757,
#  382.0212268608096]

# %%
plt.plot(range(1,11),wcss)

# %%
km = KMeans(n_clusters=4)
y_pred = km.fit_predict(X)

# %%
df = pd.DataFrame()   ##yha pe hmaare pass agr 3 se jada column hote to code yhi hota bus line add ho jati :row and 3,4,5,6 colums ----[:,3],[:,4] and so on .

df['col1'] = X[:,0]
df['col2'] = X[:,1]
df['col3'] = X[:,2]
df['label'] = y_pred

# %%
df.head()
# Out:
#        col1      col2      col3  label
# 0  4.334245  3.325804 -4.174970      3
# 1 -3.322467  3.221711 -4.625342      0
# 2 -6.072969 -4.134592  2.698461      1
# 3  6.904659  6.111057 -4.340950      3
# 4 -2.608392  2.950156 -2.234665      0

# %%
grouped = df.groupby('label')

# %%
cluster_2 = grouped.get_group(2)
print(cluster_2) # cluster data 

#print(cluster_2.iloc[19]) #  specific row data in cluster
# Out:
#          col1      col2      col3  label
# 16   2.702730 -2.217324  3.173903      2
# 17   4.064383 -0.362172  3.214466      2
# 18   4.692686 -2.737942  5.155288      2
# 19   4.121083 -1.543878  3.294159      2
# 21   3.057771 -2.176473  3.890009      2
# 27   3.309779 -2.948738  3.327552      2
# 30   1.462799 -4.442589  1.493559      2
# 38   3.020843 -2.149833  4.017165      2
# 39   3.824274 -2.478137  3.531326      2
# 45   4.308844 -0.710245  4.451284      2
# 46   3.586464 -4.642467  3.169831      2
# 51   3.324541 -3.433915  3.466980      2
# 52   3.450297 -2.033357  5.033687      2
# 57   2.073445 -0.732040  3.524627      2
# 58   4.117986 -2.684176  3.884015      2
# 64   3.961164 -3.675983  5.010127      2
# 66   2.900195 -1.376588  4.305267      2
# 70   3.070858 -1.291544  5.115702      2
# 79   3.938166 -1.377672  3.002980      2
# 93   5.610605 -3.806534  4.076380      2
# 107  4.353281 -2.913029  5.834718      2
# 108  2.798656 -3.037223  4.156264      2
# ...

# %%
fig = px.scatter_3d(df,x='col1', y='col2', z='col3',color='label')
fig.show()

# %% [markdown]
# ### prediction new value

# %%
new_point = [3.4, -2.6, 4.1]
cluster = km.predict([new_point])
print(cluster)
# Out:
# [2]
